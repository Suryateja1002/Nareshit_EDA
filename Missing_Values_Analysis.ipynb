# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import numpy as np
import pandas as pd

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
dict1
# Out:
# {'Names': ['Ramesh', 'Suresh', nan, 'Mahesh'],
#  'Age': [31, 32, 33, nan],
#  'City': [nan, 'Hyd', 'Mumbai', 'Chennai']}

# %%
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
data1.isnull()
# Out:
#    Names    Age   City
# 0  False  False   True
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False

# %%
data1.isnull().sum()
# every column has one missing value
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
# missing value count in percentages
data1.isnull().sum()/len(data1)
# Out:
# Names    0.25
# Age      0.25
# City     0.25
# dtype: float64

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
dict2={'Names':['Ramesh','Suresh',None,'Mahesh'],
      'Age':[31,32,33,None],
      'City':[None,'Hyd','Mumbai','Chennai']}
data2=pd.DataFrame(dict2)
data2
# Out:
#     Names   Age     City
# 0  Ramesh  31.0     None
# 1  Suresh  32.0      Hyd
# 2    None  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
data2.isnull()
# Out:
#    Names    Age   City
# 0  False  False   True
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False

# %% [markdown]
# # **Important**
# - NaN-------------> for Numerical
# - None------------> for Categorical

# %%
dict3={'Names':['Ramesh','Suresh','Null','Mahesh'],
      'Age':[31,32,33,'Null'],
      'City':['Null','Hyd','Mumbai','Chennai']}
data3=pd.DataFrame(dict3)
data3
# Out:
#     Names   Age     City
# 0  Ramesh    31     Null
# 1  Suresh    32      Hyd
# 2    Null    33   Mumbai
# 3  Mahesh  Null  Chennai

# %%
data3.isnull()
# Out:
#    Names    Age   City
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %% [markdown]
# # **Method-1**
# > Fill Missing values with random numbers
# - dataframe name = data1
# - methodname: fillna

# %%
data1.fillna(40)
# Out:
#     Names   Age     City
# 0  Ramesh  31.0       40
# 1  Suresh  32.0      Hyd
# 2      40  33.0   Mumbai
# 3  Mahesh  40.0  Chennai

# %%
# **Method-2**
> Fill the Missing values with random numbers on Specific column

# %%
data1['Names'].fillna('Suresh')
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Suresh
# 3    Mahesh
# Name: Names, dtype: object

# %%
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %% [markdown]
# # it is not override to do that we need to use inplace=True

# %%
data1['Names'].fillna('Suresh',inplace=True)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2  Suresh  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2  Suresh  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %% [markdown]
# # **Method-3**
# - **bfill**
# - **ffill**
# - **pad**
# - **backfill**

# %%
data1.fillna(method='backfill')
# Names index 2 is missing value
# backfill will replace NaN by index-3 value

# Age index-3 is missing value
# we don't have index-4 , so the value is NaN 

# City index-0 is missing value
# backfill will replace NaN by index-1 value
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      Hyd
# 1  Suresh  32.0      Hyd
# 2  Mahesh  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
data1.fillna(method='bfill')
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      Hyd
# 1  Suresh  32.0      Hyd
# 2  Mahesh  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
data1.fillna(method='ffill')
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2  Suresh  33.0   Mumbai
# 3  Mahesh  33.0  Chennai

# %%
data1.fillna(method='pad')
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2  Suresh  33.0   Mumbai
# 3  Mahesh  33.0  Chennai

# %% [markdown]
# # **important**
# - **bfill sameas backfill**
# - **ffill same as pad**

# %% [markdown]
# # **Method-4**
# - **Mean**
# - **Mode**
# - **Median**

# %%
age_mean=data1['Age'].mean()
age_mean
# Out:
# 32.0

# %%
# instead of providing a random number
# we are filling with mean of the data
data1['Age'].fillna(age_mean,inplace=True)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh  32.0  Chennai

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
age_median=data1['Age'].median()
data1['Age'].fillna(age_median,inplace=True)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh  32.0  Chennai

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
age_mode=data1['Age'].mode()
data1['Age'].fillna(age_mode,inplace=True)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
dict1={'Names':['Ramesh','Suresh',np.nan,'Mahesh'],
      'Age':[31,32,33,np.nan],
      'City':[np.nan,'Hyd','Mumbai','Chennai']}
data1=pd.DataFrame(dict1)
data1
# Out:
#     Names   Age     City
# 0  Ramesh  31.0      NaN
# 1  Suresh  32.0      Hyd
# 2     NaN  33.0   Mumbai
# 3  Mahesh   NaN  Chennai

# %%
# Level1: Mean Mode Median
# Level2:bfill fill
# Level3:KNN imputer (K- nearest neighbour)

# %% [markdown]
# # **Method-5**

# %% [markdown]
# # **KNN imputer**
# - KNN - K- nearest neighbour
# - in knn instead of taking mean of all the values
# - we will choose neighbour data
# - we will take those mean only

# %%
from sklearn.impute import KNNImputer
knn=KNNImputer(n_neighbors=2)
knn.fit_transform(data1[['Age']])
# Out:
# array([[31.],
#        [32.],
#        [33.],
#        [32.]])

# %% [markdown]
# # **Method-6**
# > **Based on other columns**
#
# - sometimes all above methods will not provide good justification
# - at that time we need to check other columns dependency also
# - most of the time we will pick a column which has highest correlation
