# %% [markdown]
# # Categorical vs Numerical

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - In machine learning it is very important to convert Categorical data to Numerical data
# - Machine Learning models are developed based on maths
# - ML takes input in the form of numbers only
# - to convert them we have some encoding techniques
#     - 1)**Label Encoder**
#         - map
#         - np.where
#         - using sklearn package
#     - 2)**One hot encoder**
#         - using pandas package pd.get_dummies

# %% [markdown]
# # **map method**
# - before applying map method first get the unique labels of the column
# - for example case_status is a categorical column
# - it has two unique labels they are
#     - Denied and
#     - Certified
# - Create a dictionary
#     - key as label
#     - valu as number
# - d={'Certified':0,'Denied':1}
# - The dictionary we need to map the case_status column

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# map method
d={'Certified':0,'Denied':1}
#overriding is best option
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# continent column
# use map method
d1={}
unique_labels=visa_df['continent'].unique()
for i in range(len(unique_labels)):
    d1[unique_labels[i]]=i
visa_df['continent']=visa_df['continent'].map(d1)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # **traditional_method**

# %%
# for all the categorical columns
# read the data
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)

# get categprical columns out
cat_cols=visa_df.select_dtypes(include='object').columns
d1={}
for j in cat_cols[1:]:    # j------------->column
    unique_labels=visa_df[j].unique()
    for i in range(len(unique_labels)):  # i----->number
        d1[unique_labels[i]]=i
        
    visa_df[j]=visa_df[j].map(d1)
visa_df


# fails because of case_id so we use cat_cols[1:]
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# # **Note**
# - we will always drop the id columns

# %%
# we use labelencoding method to get all the above dat that we get using traditional method

# %% [markdown]
# # **LabelEncoder**
# - LabelEncoder package is available in sklearn
# - sickit learn heart of ML
# - Read the package
# - Save the package
# - Apply the fit transform (le.fit_transform(visa_df['']))

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder                   # read the package
le=LabelEncoder()                                                 # save the package
visa_df['case_status']=le.fit_transform(visa_df['case_status'])  # Apply the fit transform 
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat_cols=visa_df.select_dtypes(include='object').columns
for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])  # Apply the fit transform 
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
# above and this both are same
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
cat_cols=visa_df.select_dtypes(include='object').columns


from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])  # Apply the fit transform 
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# # **To convert the converted Numerical data to Categorical data**
# - le.inverse_transform()

# %%
le.inverse_transform(visa_df['continent'])
# getting error because from above code inverse transform is taking the last column i.e; 'case_status'
# so to avoid this we read individual columns in fit transform and try to corvert using inverse transform
# ValueError: y contains previously unseen labels: [2 3 4 5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 le.inverse_transform(visa_df['continent'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:160, in LabelEncoder.inverse_transform(self, y)
#     158 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     159 if len(diff):
# --> 160     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     161 y = np.asarray(y)
#     162 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [2 3 4 5]

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
cat_cols=visa_df.select_dtypes(include='object').columns


from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])  # Apply the fit transform 
visa_df['continent']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: continent, Length: 25480, dtype: int32

# %%
# now we apply inverse transform for above single column 'continent'
le.inverse_transform(visa_df['continent'])
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %% [markdown]
# # ***np.where***
# - It is applicable for only binary(two) labels
# - in case status column we have only two labels 'Certified' and 'Denied'
# - If case_status == 'Certified' replace that as 0, otherwise 1
# - np.where requires three arguments
#     - condition
#     - True
#     - False

# %%
np.where(visa_df['case_status'] == 'Certified',1,0)
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %% [markdown]
# # ****onehot encoder****
# - It means at a time one will ON and other will OFF
# - In case status column we have only two labels 'Certified' and 'Denied'
# - when we apply onehot encoder on 'case_status' it will create two more extra columns
#     - case_status_certified
#     - case_status_denied
#
#
# |case_status|  case_status_certified |   case_status_denied
# |-|-|-|
# |certified|
# |denied|
#
#
# - ----------------------------------------------------------------------------------------------------
# - ***Advantage of using onehot encoder***
#     - if we develop an ML model it is very important thee columns should be independent to each other
#     - so by using onehot encoder we can create for case_status  two extra columns
#     - which are independent to each other
#     - which means the row values at a time only one column has value 1.
#     - Columns are independent to each other
#     - which means **90 degrees phase shift**
#     - which means **Perpendicular to each other**
#     - which means **Orthogonal to each other**
# - -------------------------------------------------------------------------------------------------------
# - ***Disadvantage of using onehot encoder***
#     - If a column has 100 unique labels , onehot encoder will create 100 new columns
#     - The data will became sparse, which means huge
#     - Columns are more meaning Dimensions are more
#     - So that **Processing time** will be more
#     - The **Memory Consumption** will be more
#     - leads to
#     - **Curse of Dimensionality**
# - --------------------------------------------------------------------------------------------------------
# - **pd.getdummies()**

# %% [markdown]
# # pd.getdummies()

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# when we don't mention column names will take all the columns in the visa_df
pd.get_dummies(visa_df)
# observe columns we have 25510 columns here
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029            True
# 1                 2412         2002       83425.6500           False
# 2                44444         2008      122996.8600           False
# 3                   98         1897       83434.0300           False
# 4                 1082         2005      149907.3900           False
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700           False
# 25476             3274         2006      279174.7900           False
# 25477             1121         1910      146298.8500           False
# 25478             1918         1887       86154.7700           False
# 25479             3195         1960       70876.9100           False
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
pd.get_dummies(visa_df['education_of_employee'])
# Out:
#        Bachelor's  Doctorate  High School  Master's
# 0           False      False         True     False
# 1           False      False        False      True
# 2            True      False        False     False
# 3            True      False        False     False
# 4           False      False        False      True
# ...           ...        ...          ...       ...
# 25475        True      False        False     False
# 25476       False      False         True     False
# 25477       False      False        False      True
# 25478       False      False        False      True
# 25479        True      False        False     False
#
# [25480 rows x 4 columns]

# %%
# above 4columns are added to visa_df
pd.get_dummies(visa_df,columns=['education_of_employee'])
# Out:
#          case_id continent has_job_experience requires_job_training  \
# 0         EZYV01      Asia                  N                     N
# 1         EZYV02      Asia                  Y                     N
# 2         EZYV03      Asia                  N                     Y
# 3         EZYV04      Asia                  N                     N
# 4         EZYV05    Africa                  Y                     N
# ...          ...       ...                ...                   ...
# 25475  EZYV25476      Asia                  Y                     Y
# 25476  EZYV25477      Asia                  Y                     N
# 25477  EZYV25478      Asia                  Y                     N
# 25478  EZYV25479      Asia                  Y                     Y
# 25479  EZYV25480      Asia                  Y                     N
#
#        no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0                14513         2007                 West         592.2029
# ...

# %%
pd.get_dummies(visa_df['case_status'])
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
# above 4columns are added to visa_df
pd.get_dummies(visa_df,columns=['case_status'])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# now getting dummies of multiple columns
pd.get_dummies(visa_df,columns=['education_of_employee','case_status'])
# Out:
#          case_id continent has_job_experience requires_job_training  \
# 0         EZYV01      Asia                  N                     N
# 1         EZYV02      Asia                  Y                     N
# 2         EZYV03      Asia                  N                     Y
# 3         EZYV04      Asia                  N                     N
# 4         EZYV05    Africa                  Y                     N
# ...          ...       ...                ...                   ...
# 25475  EZYV25476      Asia                  Y                     Y
# 25476  EZYV25477      Asia                  Y                     N
# 25477  EZYV25478      Asia                  Y                     N
# 25478  EZYV25479      Asia                  Y                     Y
# 25479  EZYV25480      Asia                  Y                     N
#
#        no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0                14513         2007                 West         592.2029
# ...

# %% [markdown]
# # the dummy columns are coming as true and False
# # to get them as 1 and 0
# # we need to use dtype=int

# %%
pd.get_dummies(visa_df,columns=['education_of_employee','case_status'],dtype=int)
# Out:
#          case_id continent has_job_experience requires_job_training  \
# 0         EZYV01      Asia                  N                     N
# 1         EZYV02      Asia                  Y                     N
# 2         EZYV03      Asia                  N                     Y
# 3         EZYV04      Asia                  N                     N
# 4         EZYV05    Africa                  Y                     N
# ...          ...       ...                ...                   ...
# 25475  EZYV25476      Asia                  Y                     Y
# 25476  EZYV25477      Asia                  Y                     N
# 25477  EZYV25478      Asia                  Y                     N
# 25478  EZYV25479      Asia                  Y                     Y
# 25479  EZYV25480      Asia                  Y                     N
#
#        no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0                14513         2007                 West         592.2029
# ...

# %% [markdown]
# # we are getting 25510 columns here because of the case_id column
# - because it has 25480unique values
# - so drop it

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)

# drop the case_id column
visa_df.drop('case_id',axis=1,inplace=True)

# when we don't mention column names will take all the columns in the visa_df
pd.get_dummies(visa_df,dtype=int)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# # mostly we use label encoder
