# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
df=pd.read_csv(path)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # -  head and tail
# # -  shape and size
# # -  columns
# # -  type

# %%
df.head(15)
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 0   EZYV01           Asia           High School                  N
# 1   EZYV02           Asia              Master's                  Y
# 2   EZYV03           Asia            Bachelor's                  N
# 3   EZYV04           Asia            Bachelor's                  N
# 4   EZYV05         Africa              Master's                  Y
# 5   EZYV06           Asia              Master's                  Y
# 6   EZYV07           Asia            Bachelor's                  N
# 7   EZYV08  North America            Bachelor's                  Y
# 8   EZYV09           Asia            Bachelor's                  N
# 9   EZYV10         Europe             Doctorate                  Y
# 10  EZYV11           Asia              Master's                  N
# 11  EZYV12           Asia           High School                  Y
# 12  EZYV13           Asia            Bachelor's                  Y
# ...

# %%
df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# # shape
# - shape is a keyword not a function

# %%
df.shape
# Out:
# (25480, 12)

# %%
print("No of rows = ",df.shape[0])
print("No of columns = ",df.shape[1])
# Out:
# No of rows =  25480
# No of columns =  12

# %% [markdown]
# # size

# %%
df.size   # 25480 * 12 = 305760
# Out:
# 305760

# %% [markdown]
# # columns

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # dtypes

# %%
df.dtypes
# object -------------> catogerical data 
# others -------------> numerical data
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # types
# - df = pandas.core.frame.DataFrame
#
# - df.columns = pandas.core.indexes.base.Index
#
# - df.datatypes = pandas.core.series.Series

# %% [markdown]
# # important

# %%
# By using dtypes extract numerical columns and categorical columns


# converting df.datatypes to dictionary
dict1=dict(df.dtypes)
print(dict1)
num=[]
cat=[]
for i in dict1:
    print(i,dict1[i])
    if dict1[i]=='object':
        cat.append(i)
    else:
        num.append(i)

cat,num
# Out:
# {'case_id': dtype('O'), 'continent': dtype('O'), 'education_of_employee': dtype('O'), 'has_job_experience': dtype('O'), 'requires_job_training': dtype('O'), 'no_of_employees': dtype('int64'), 'yr_of_estab': dtype('int64'), 'region_of_employment': dtype('O'), 'prevailing_wage': dtype('float64'), 'unit_of_wage': dtype('O'), 'full_time_position': dtype('O'), 'case_status': dtype('O')}
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
# method-2
num=[i for i in dict1 if dict1[i] == 'object']
cat=[i for i in dict1 if dict1[i] != 'object']
num,cat
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# # select_dtype

# %%
df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
df.select_dtypes(exclude='object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %% [markdown]
# # isnull
# - identify if data has any missing values or Null value

# %%
df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# # Note:-
# - when we open excel sheet the data has empty cell means data is missing
# - if we read that using pandas at that particular missing position it will display as NULL
# - to identify count of missing values based on columns we use df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# # df.drop_duplicates()
# - to drop duplicate values

# %%
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # df.info()
# - all the info such as dtype,count etc..

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
len(df)
# Out:
# 25480

# %% [markdown]
# # Methods
# - df.head()
# - df.tail()
# - df.shape()
# - df.size()
# - df.columns()
# - df.dtypes()
# - df.select_dtypes()
# - df.isnull()
# - df.isnull().sum()
# - df.drop_duplicates()
# - df.info()
# - len(df)

# %% [markdown]
# # Bound method
# - we need to keep brackets
#
# # not callable
# - you need to remove brackets
#
# # Attribute Error
# - the method is not available
# - check for spelling mistake
#
# - ___________________________________

# %% [markdown]
# # to get a specific row
# - head will give top n rows
# - tail will give bottom n rows
# - but for a specific row we need take,loc,iloc
#
# # take , loc , iloc
# - take([]) ---> we need give value in [] or () inside df.take()

# %%
df.take([2])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied

# %%
df.take([2,3,4,5,6])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
# 6  EZYV07      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# ...

# %%
df.take((2))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.take((2))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3909, in NDFrame.take(self, indices, axis, **kwargs)
#    3833 """
#    3834 Return the elements in the given *positional* indices along an axis.
#    3835
#    (...)
#    3904 3    lion  mammal       80.5
#    3905 """
#    3907 nv.validate_take((), kwargs)
# -> 3909 return self._take(indices, axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3924     if (
#    3925         axis == 0
#    3926         and indices.ndim == 1
#    3927         and using_copy_on_write()
#    3928         and is_range_indexer(indices, len(self))
#    3929     ):
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
# ...

# %%
df.take((2,3,4,5,6))
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
# 6  EZYV07      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# ...

# %% [markdown]
# # Important

# %%
# row ----> 100,200, 300 Col-------> 4,8,11
df.take([100,200,300]).take([4,8,11],axis=1)
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %% [markdown]
# # Drawback in take()
# - take don't take rows and columns at a time
# - so we use iloc()

# %% [markdown]
# # iloc[]
# - iloc takes [] brackets not()
# - df.iloc[<rows>,<columns>]
# - df.iloc[<start:end>,<columns[start:end]>]
# - df.iloc[rows,columns]

# %%
# specific rows and specific columns
df.iloc[2:5,4:6]
# Out:
#   requires_job_training  no_of_employees
# 2                     Y            44444
# 3                     N               98
# 4                     N             1082

# %%
# all rows and specific columns
df.iloc[:,2:5]
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
# all columns and specified rows
df.iloc[2:5]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %% [markdown]
# # Important

# %%
# row ----> 100,200, 300 Col-------> 4,8,11
df.iloc[[100,200,300],[4,8,11]]
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %% [markdown]
# - No brackets   -------> series
# - brackets  ------------> dataframe

# %%
df.iloc[[100,200,300],8]
# Out:
# 100     28243.79
# 200     74441.11
# 300    101371.21
# Name: prevailing_wage, dtype: float64

# %%
df.iloc[[100,200,300],[8]]
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %% [markdown]
# # Drawback of iloc
# - if we want a specific column we need to use loc with that column name in the list

# %% [markdown]
# # loc

# %%
df.loc[[100,200,300],['prevailing_wage']]
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %% [markdown]
# # Methods
# - df.head()
# - df.tail()
# - df.shape()
# - df.size()
# - df.columns()
# - df.dtypes()
# - df.select_dtypes()
# - df.isnull()
# - df.isnull().sum()
# - df.drop_duplicates()
# - df.info()
# - len(df)
# - df.take()
# - df.iloc[]
# - df.loc[]
