# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1=r"C:\Users\surya\Downloads\Python files\Visadataset.csv"
visa_df=pd.read_csv(file1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # **prevailing_wage**
# - mean
# - median
# - standard deviation
# - count
# - 25p,50p

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %% [markdown]
# # **Count**
# - len()
# - .count()

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
visa_df['prevailing_wage'].count()
# Out:
# 25480

# %% [markdown]
# # **mean**

# %%
round(visa_df['prevailing_wage'].mean(),2)   #------> pandas
# Out:
# 74455.81

# %%
# using numpy
round(np.mean(visa_df['prevailing_wage']),2)
# Out:
# 74455.81

# %% [markdown]
# # **median**

# %%
visa_df['prevailing_wage'].median()  #----->pandas
# Out:
# 70308.20999999999

# %%
#numpy
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %% [markdown]
# # **Standard Deviation**

# %%
visa_df['prevailing_wage'].std()
# Out:
# 52815.94232687357

# %%
# numpy
np.std(visa_df['prevailing_wage'])
# Out:
# 52814.90589711402

# %% [markdown]
# # **max and min**

# %%
max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
# using pandas
wage_count=round(visa_df['prevailing_wage'].count(),2)
wage_max=round(max(visa_df['prevailing_wage']),2)
wage_min=round(min(visa_df['prevailing_wage']),2)
wage_mean=round(visa_df['prevailing_wage'].mean(),2)  
wage_median=round(visa_df['prevailing_wage'].median(),2)
wage_std=round(visa_df['prevailing_wage'].std(),2)


l=[wage_count,wage_max,wage_min,wage_mean,wage_median,wage_std]
cols=['prevailing_wage']
index=['count','max','min','mean','median','std']
df=pd.DataFrame(l,columns=cols,index=index)
df
# Out:
#         prevailing_wage
# count          25480.00
# max           319210.27
# min                2.14
# mean           74455.81
# median         70308.21
# std            52815.94

# %% [markdown]
# # ** Quantile , percentile **
# - percentile and quantile available in numpy
# - **np.percentile() takes two cols**
#     - col name
#     - percentile value  between 0 to 100
# - **np.quantile() takes two cols**
#     - col name
#     - quantile value betwwen 0 to 1
#
# - **in quantile 0.25 mean 25 in percentile**

# %%
wage_25p=np.percentile(visa_df['prevailing_wage'],25)
wage_25p
# Out:
# 34015.479999999996

# %%
np.quantile(visa_df['prevailing_wage'],0.25)
# Out:
# 34015.479999999996

# %% [markdown]
# **what is the meaning 0f 25p=34015.47**
# - 25p of the total wage less than 34015.47
# - Find 25p of the total data = 25*25480/100=6370
# - 6370 persons wage less than 34014

# %%
con=visa_df['prevailing_wage']<34014
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# 50p
np.quantile(visa_df['prevailing_wage'],0.5)
# Out:
# 70308.20999999999

# %%
wage_50p=np.percentile(visa_df['prevailing_wage'],50)
print(wage_50p)
con=visa_df['prevailing_wage']<34014
visa_df[con]
# Out:
# 70308.20999999999
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# using pandas
wage_count=round(visa_df['prevailing_wage'].count(),2)
wage_max=round(max(visa_df['prevailing_wage']),2)
wage_min=round(min(visa_df['prevailing_wage']),2)
wage_mean=round(visa_df['prevailing_wage'].mean(),2)  
wage_median=round(visa_df['prevailing_wage'].median(),2)
wage_std=round(visa_df['prevailing_wage'].std(),2)
wage_25p=np.percentile(visa_df['prevailing_wage'],25)
wage_50p=np.percentile(visa_df['prevailing_wage'],50)
wage_75p=np.percentile(visa_df['prevailing_wage'],75)

l=[wage_count,wage_max,wage_min,wage_mean,wage_median,wage_std,wage_25p,wage_50p,wage_75p]
cols=['prevailing_wage']
index=['count','max','min','mean','median','std','25%','50%','75%']
df=pd.DataFrame(l,columns=cols,index=index)
df
# Out:
#         prevailing_wage
# count        25480.0000
# max         319210.2700
# min              2.1400
# mean         74455.8100
# median       70308.2100
# std          52815.9400
# 25%          34015.4800
# 50%          70308.2100
# 75%         107735.5125

# %%
#  above all using for loop---> for 3 cols no_of_employees,yr_of_estab,prevailing_wage
# usind list

#_______________________ Method_1 ______________________
cols=visa_df.select_dtypes(exclude='object').columns
l=[]
for i in cols:
    count=round(visa_df[i].count(),2)
    maxx=round(max(visa_df[i]),2)
    minn=round(min(visa_df[i]),2)
    mean=round(visa_df[i].mean(),2)  
    median=round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)
    p_25=np.percentile(visa_df[i],25)
    p_50=np.percentile(visa_df[i],50)
    p_75=np.percentile(visa_df[i],75)
    l.append([count,maxx,minn,mean,median,std,p_25,p_50,p_75])
index=['count','max','min','mean','median','std','25%','50%','75%']
pd.DataFrame(zip(l[0],l[1],l[2]),columns=cols,index=index)
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# max           602069.00      2016.00      319210.2700
# min              -26.00      1800.00           2.1400
# mean            5667.04      1979.41       74455.8100
# median          2109.00      1997.00       70308.2100
# std            22877.93        42.37       52815.9400
# 25%             1022.00      1976.00       34015.4800
# 50%             2109.00      1997.00       70308.2100
# 75%             3504.00      2005.00      107735.5125

# %%
#  above all using for loop---> for 3 cols no_of_employees,yr_of_estab,prevailing_wage
# usind Dictionary

#_______________________ Method_2 ______________________

cols=visa_df.select_dtypes(exclude='object').columns
dict={}
for i in cols:
    count=round(visa_df[i].count(),2)
    maxx=round(max(visa_df[i]),2)
    minn=round(min(visa_df[i]),2)
    mean=round(visa_df[i].mean(),2)  
    median=round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)
    p_25=np.percentile(visa_df[i],25)
    p_50=np.percentile(visa_df[i],50)
    p_75=np.percentile(visa_df[i],75)
    dict[i]=[count,maxx,minn,mean,median,std,p_25,p_50,p_75]
index=['count','max','min','mean','median','std','25%','50%','75%']
pd.DataFrame(dict,columns=cols,index=index)
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# max           602069.00      2016.00      319210.2700
# min              -26.00      1800.00           2.1400
# mean            5667.04      1979.41       74455.8100
# median          2109.00      1997.00       70308.2100
# std            22877.93        42.37       52815.9400
# 25%             1022.00      1976.00       34015.4800
# 50%             2109.00      1997.00       70308.2100
# 75%             3504.00      2005.00      107735.5125

# %%
# all the above process using method
- visa_df.describe() -------------> will give all mean,median,std,25p,50p,75p,min,max,count

# %%
#_______________________ Method_3 ______________________
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000
